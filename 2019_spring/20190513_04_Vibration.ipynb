# %%
from nptdms import TdmsFile
import numpy as np
import pandas as pd

#set Tdms file path
tdms1 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 113528.tdms')
tdms2 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 113629.tdms')
tdms3 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 113729.tdms')
tdms4 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 113829.tdms')
tdms5 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 113930.tdms')
tdms6 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114030.tdms')
tdms7 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114130.tdms')
tdms8 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114231.tdms')
tdms9 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114331.tdms')
tdms10 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114431.tdms')
tdms11 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114532.tdms')
tdms12 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114632.tdms')
tdms13 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114732.tdms')
tdms14 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114832.tdms')
tdms15 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 114933.tdms')
tdms16 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115033.tdms')
tdms17 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115133.tdms')
tdms18 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115234.tdms')
tdms19 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115334.tdms')
tdms20 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115434.tdms')
tdms21 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115534.tdms')
tdms22 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115635.tdms')
tdms23 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115735.tdms')
tdms24 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115835.tdms')
tdms25 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 115936.tdms')
tdms26 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 120036.tdms')
tdms27 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 120136.tdms')
tdms28 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 120236.tdms')
tdms29 = TdmsFile(r'D:\data\20190513\04\Acc 05-13-19 时间 120337.tdms')



# set variable for TDMS groups
group_name = 'Measured Data'

# %% [markdown]
# # set objects for TDMS channels

# %% [markdown]
# ## x_0

# %%
channel_x_0_1 = tdms1.object(group_name, 'x_0')
channel_x_0_2 = tdms2.object(group_name, 'x_0')
channel_x_0_3 = tdms3.object(group_name, 'x_0')
channel_x_0_4 = tdms4.object(group_name, 'x_0')
channel_x_0_5 = tdms5.object(group_name, 'x_0')
channel_x_0_6 = tdms6.object(group_name, 'x_0')
channel_x_0_7 = tdms7.object(group_name, 'x_0')
channel_x_0_8 = tdms8.object(group_name, 'x_0')
channel_x_0_9 = tdms9.object(group_name, 'x_0')
channel_x_0_10 = tdms10.object(group_name, 'x_0')
channel_x_0_11 = tdms11.object(group_name, 'x_0')
channel_x_0_12 = tdms12.object(group_name, 'x_0')
channel_x_0_13 = tdms13.object(group_name, 'x_0')
channel_x_0_14 = tdms14.object(group_name, 'x_0')
channel_x_0_15 = tdms15.object(group_name, 'x_0')
channel_x_0_16 = tdms16.object(group_name, 'x_0')
channel_x_0_17 = tdms17.object(group_name, 'x_0')
channel_x_0_18 = tdms18.object(group_name, 'x_0')
channel_x_0_19 = tdms19.object(group_name, 'x_0')
channel_x_0_20 = tdms20.object(group_name, 'x_0')
channel_x_0_21 = tdms21.object(group_name, 'x_0')
channel_x_0_22 = tdms22.object(group_name, 'x_0')
channel_x_0_23 = tdms23.object(group_name, 'x_0')
channel_x_0_24 = tdms24.object(group_name, 'x_0')
channel_x_0_25 = tdms25.object(group_name, 'x_0')
channel_x_0_26 = tdms26.object(group_name, 'x_0')
channel_x_0_27 = tdms27.object(group_name, 'x_0')
channel_x_0_28 = tdms28.object(group_name, 'x_0')
channel_x_0_29 = tdms29.object(group_name, 'x_0')

# %% [markdown]
# ## y_0

# %%
channel_y_0_1 = tdms1.object(group_name, 'y_0')
channel_y_0_2 = tdms2.object(group_name, 'y_0')
channel_y_0_3 = tdms3.object(group_name, 'y_0')
channel_y_0_4 = tdms4.object(group_name, 'y_0')
channel_y_0_5 = tdms5.object(group_name, 'y_0')
channel_y_0_6 = tdms6.object(group_name, 'y_0')
channel_y_0_7 = tdms7.object(group_name, 'y_0')
channel_y_0_8 = tdms8.object(group_name, 'y_0')
channel_y_0_9 = tdms9.object(group_name, 'y_0')
channel_y_0_10 = tdms10.object(group_name, 'y_0')
channel_y_0_11 = tdms11.object(group_name, 'y_0')
channel_y_0_12 = tdms12.object(group_name, 'y_0')
channel_y_0_13 = tdms13.object(group_name, 'y_0')
channel_y_0_14 = tdms14.object(group_name, 'y_0')
channel_y_0_15 = tdms15.object(group_name, 'y_0')
channel_y_0_16 = tdms16.object(group_name, 'y_0')
channel_y_0_17 = tdms17.object(group_name, 'y_0')
channel_y_0_18 = tdms18.object(group_name, 'y_0')
channel_y_0_19 = tdms19.object(group_name, 'y_0')
channel_y_0_20 = tdms20.object(group_name, 'y_0')
channel_y_0_21 = tdms21.object(group_name, 'y_0')
channel_y_0_22 = tdms22.object(group_name, 'y_0')
channel_y_0_23 = tdms23.object(group_name, 'y_0')
channel_y_0_24 = tdms24.object(group_name, 'y_0')
channel_y_0_25 = tdms25.object(group_name, 'y_0')
channel_y_0_26 = tdms26.object(group_name, 'y_0')
channel_y_0_27 = tdms27.object(group_name, 'y_0')
channel_y_0_28 = tdms28.object(group_name, 'y_0')
channel_y_0_29 = tdms29.object(group_name, 'y_0')

# %% [markdown]
# ## z_0

# %%
channel_z_0_1 = tdms1.object(group_name, 'z_0')
channel_z_0_2 = tdms2.object(group_name, 'z_0')
channel_z_0_3 = tdms3.object(group_name, 'z_0')
channel_z_0_4 = tdms4.object(group_name, 'z_0')
channel_z_0_5 = tdms5.object(group_name, 'z_0')
channel_z_0_6 = tdms6.object(group_name, 'z_0')
channel_z_0_7 = tdms7.object(group_name, 'z_0')
channel_z_0_8 = tdms8.object(group_name, 'z_0')
channel_z_0_9 = tdms9.object(group_name, 'z_0')
channel_z_0_10 = tdms10.object(group_name, 'z_0')
channel_z_0_11 = tdms11.object(group_name, 'z_0')
channel_z_0_12 = tdms12.object(group_name, 'z_0')
channel_z_0_13 = tdms13.object(group_name, 'z_0')
channel_z_0_14 = tdms14.object(group_name, 'z_0')
channel_z_0_15 = tdms15.object(group_name, 'z_0')
channel_z_0_16 = tdms16.object(group_name, 'z_0')
channel_z_0_17 = tdms17.object(group_name, 'z_0')
channel_z_0_18 = tdms18.object(group_name, 'z_0')
channel_z_0_19 = tdms19.object(group_name, 'z_0')
channel_z_0_20 = tdms20.object(group_name, 'z_0')
channel_z_0_21 = tdms21.object(group_name, 'z_0')
channel_z_0_22 = tdms22.object(group_name, 'z_0')
channel_z_0_23 = tdms23.object(group_name, 'z_0')
channel_z_0_24 = tdms24.object(group_name, 'z_0')
channel_z_0_25 = tdms25.object(group_name, 'z_0')
channel_z_0_26 = tdms26.object(group_name, 'z_0')
channel_z_0_27 = tdms27.object(group_name, 'z_0')
channel_z_0_28 = tdms28.object(group_name, 'z_0')
channel_z_0_29 = tdms29.object(group_name, 'z_0')

# %% [markdown]
# ## x_1

# %%
channel_x_1_1 = tdms1.object(group_name, 'x_1')
channel_x_1_2 = tdms2.object(group_name, 'x_1')
channel_x_1_3 = tdms3.object(group_name, 'x_1')
channel_x_1_4 = tdms4.object(group_name, 'x_1')
channel_x_1_5 = tdms5.object(group_name, 'x_1')
channel_x_1_6 = tdms6.object(group_name, 'x_1')
channel_x_1_7 = tdms7.object(group_name, 'x_1')
channel_x_1_8 = tdms8.object(group_name, 'x_1')
channel_x_1_9 = tdms9.object(group_name, 'x_1')
channel_x_1_10 = tdms10.object(group_name, 'x_1')
channel_x_1_11 = tdms11.object(group_name, 'x_1')
channel_x_1_12 = tdms12.object(group_name, 'x_1')
channel_x_1_13 = tdms13.object(group_name, 'x_1')
channel_x_1_14 = tdms14.object(group_name, 'x_1')
channel_x_1_15 = tdms15.object(group_name, 'x_1')
channel_x_1_16 = tdms16.object(group_name, 'x_1')
channel_x_1_17 = tdms17.object(group_name, 'x_1')
channel_x_1_18 = tdms18.object(group_name, 'x_1')
channel_x_1_19 = tdms19.object(group_name, 'x_1')
channel_x_1_20 = tdms20.object(group_name, 'x_1')
channel_x_1_21 = tdms21.object(group_name, 'x_1')
channel_x_1_22 = tdms22.object(group_name, 'x_1')
channel_x_1_23 = tdms23.object(group_name, 'x_1')
channel_x_1_24 = tdms24.object(group_name, 'x_1')
channel_x_1_25 = tdms25.object(group_name, 'x_1')
channel_x_1_26 = tdms26.object(group_name, 'x_1')
channel_x_1_27 = tdms27.object(group_name, 'x_1')
channel_x_1_28 = tdms28.object(group_name, 'x_1')
channel_x_1_29 = tdms29.object(group_name, 'x_1')

# %% [markdown]
# ## y_1

# %%
channel_y_1_1 = tdms1.object(group_name, 'y_1')
channel_y_1_2 = tdms2.object(group_name, 'y_1')
channel_y_1_3 = tdms3.object(group_name, 'y_1')
channel_y_1_4 = tdms4.object(group_name, 'y_1')
channel_y_1_5 = tdms5.object(group_name, 'y_1')
channel_y_1_6 = tdms6.object(group_name, 'y_1')
channel_y_1_7 = tdms7.object(group_name, 'y_1')
channel_y_1_8 = tdms8.object(group_name, 'y_1')
channel_y_1_9 = tdms9.object(group_name, 'y_1')
channel_y_1_10 = tdms10.object(group_name, 'y_1')
channel_y_1_11 = tdms11.object(group_name, 'y_1')
channel_y_1_12 = tdms12.object(group_name, 'y_1')
channel_y_1_13 = tdms13.object(group_name, 'y_1')
channel_y_1_14 = tdms14.object(group_name, 'y_1')
channel_y_1_15 = tdms15.object(group_name, 'y_1')
channel_y_1_16 = tdms16.object(group_name, 'y_1')
channel_y_1_17 = tdms17.object(group_name, 'y_1')
channel_y_1_18 = tdms18.object(group_name, 'y_1')
channel_y_1_19 = tdms19.object(group_name, 'y_1')
channel_y_1_20 = tdms20.object(group_name, 'y_1')
channel_y_1_21 = tdms21.object(group_name, 'y_1')
channel_y_1_22 = tdms22.object(group_name, 'y_1')
channel_y_1_23 = tdms23.object(group_name, 'y_1')
channel_y_1_24 = tdms24.object(group_name, 'y_1')
channel_y_1_25 = tdms25.object(group_name, 'y_1')
channel_y_1_26 = tdms26.object(group_name, 'y_1')
channel_y_1_27 = tdms27.object(group_name, 'y_1')
channel_y_1_28 = tdms28.object(group_name, 'y_1')
channel_y_1_29 = tdms29.object(group_name, 'y_1')

# %% [markdown]
# ## z_1

# %%
channel_z_1_1 = tdms1.object(group_name, 'z_1')
channel_z_1_2 = tdms2.object(group_name, 'z_1')
channel_z_1_3 = tdms3.object(group_name, 'z_1')
channel_z_1_4 = tdms4.object(group_name, 'z_1')
channel_z_1_5 = tdms5.object(group_name, 'z_1')
channel_z_1_6 = tdms6.object(group_name, 'z_1')
channel_z_1_7 = tdms7.object(group_name, 'z_1')
channel_z_1_8 = tdms8.object(group_name, 'z_1')
channel_z_1_9 = tdms9.object(group_name, 'z_1')
channel_z_1_10 = tdms10.object(group_name, 'z_1')
channel_z_1_11 = tdms11.object(group_name, 'z_1')
channel_z_1_12 = tdms12.object(group_name, 'z_1')
channel_z_1_13 = tdms13.object(group_name, 'z_1')
channel_z_1_14 = tdms14.object(group_name, 'z_1')
channel_z_1_15 = tdms15.object(group_name, 'z_1')
channel_z_1_16 = tdms16.object(group_name, 'z_1')
channel_z_1_17 = tdms17.object(group_name, 'z_1')
channel_z_1_18 = tdms18.object(group_name, 'z_1')
channel_z_1_19 = tdms19.object(group_name, 'z_1')
channel_z_1_20 = tdms20.object(group_name, 'z_1')
channel_z_1_21 = tdms21.object(group_name, 'z_1')
channel_z_1_22 = tdms22.object(group_name, 'z_1')
channel_z_1_23 = tdms23.object(group_name, 'z_1')
channel_z_1_24 = tdms24.object(group_name, 'z_1')
channel_z_1_25 = tdms25.object(group_name, 'z_1')
channel_z_1_26 = tdms26.object(group_name, 'z_1')
channel_z_1_27 = tdms27.object(group_name, 'z_1')
channel_z_1_28 = tdms28.object(group_name, 'z_1')
channel_z_1_29 = tdms29.object(group_name, 'z_1')

# %% [markdown]
# # set data from channels

# %% [markdown]
# ## x_0

# %%
x_0_1 = channel_x_0_1.data
x_0_2 = channel_x_0_2.data
x_0_3 = channel_x_0_3.data
x_0_4 = channel_x_0_4.data
x_0_5 = channel_x_0_5.data
x_0_6 = channel_x_0_6.data
x_0_7 = channel_x_0_7.data
x_0_8 = channel_x_0_8.data
x_0_9 = channel_x_0_9.data
x_0_10 = channel_x_0_10.data
x_0_11 = channel_x_0_11.data
x_0_12 = channel_x_0_12.data
x_0_13 = channel_x_0_13.data
x_0_14 = channel_x_0_14.data
x_0_15 = channel_x_0_15.data
x_0_16 = channel_x_0_16.data
x_0_17 = channel_x_0_17.data
x_0_18 = channel_x_0_18.data
x_0_19 = channel_x_0_19.data
x_0_20 = channel_x_0_20.data
x_0_21 = channel_x_0_21.data
x_0_22 = channel_x_0_22.data
x_0_23 = channel_x_0_23.data
x_0_24 = channel_x_0_24.data
x_0_25 = channel_x_0_25.data
x_0_26 = channel_x_0_26.data
x_0_27 = channel_x_0_27.data
x_0_28 = channel_x_0_28.data
x_0_29 = channel_x_0_29.data

# %% [markdown]
# ## y_0

# %%
y_0_1 = channel_y_0_1.data
y_0_2 = channel_y_0_2.data
y_0_3 = channel_y_0_3.data
y_0_4 = channel_y_0_4.data
y_0_5 = channel_y_0_5.data
y_0_6 = channel_y_0_6.data
y_0_7 = channel_y_0_7.data
y_0_8 = channel_y_0_8.data
y_0_9 = channel_y_0_9.data
y_0_10 = channel_y_0_10.data
y_0_11 = channel_y_0_11.data
y_0_12 = channel_y_0_12.data
y_0_13 = channel_y_0_13.data
y_0_14 = channel_y_0_14.data
y_0_15 = channel_y_0_15.data
y_0_16 = channel_y_0_16.data
y_0_17 = channel_y_0_17.data
y_0_18 = channel_y_0_18.data
y_0_19 = channel_y_0_19.data
y_0_20 = channel_y_0_20.data
y_0_21 = channel_y_0_21.data
y_0_22 = channel_y_0_22.data
y_0_23 = channel_y_0_23.data
y_0_24 = channel_y_0_24.data
y_0_25 = channel_y_0_25.data
y_0_26 = channel_y_0_26.data
y_0_27 = channel_y_0_27.data
y_0_28 = channel_y_0_28.data
y_0_29 = channel_y_0_29.data

# %% [markdown]
# ## z_0

# %%
z_0_1 = channel_z_0_1.data
z_0_2 = channel_z_0_2.data
z_0_3 = channel_z_0_3.data
z_0_4 = channel_z_0_4.data
z_0_5 = channel_z_0_5.data
z_0_6 = channel_z_0_6.data
z_0_7 = channel_z_0_7.data
z_0_8 = channel_z_0_8.data
z_0_9 = channel_z_0_9.data
z_0_10 = channel_z_0_10.data
z_0_11 = channel_z_0_11.data
z_0_12 = channel_z_0_12.data
z_0_13 = channel_z_0_13.data
z_0_14 = channel_z_0_14.data
z_0_15 = channel_z_0_15.data
z_0_16 = channel_z_0_16.data
z_0_17 = channel_z_0_17.data
z_0_18 = channel_z_0_18.data
z_0_19 = channel_z_0_19.data
z_0_20 = channel_z_0_20.data
z_0_21 = channel_z_0_21.data
z_0_22 = channel_z_0_22.data
z_0_23 = channel_z_0_23.data
z_0_24 = channel_z_0_24.data
z_0_25 = channel_z_0_25.data
z_0_26 = channel_z_0_26.data
z_0_27 = channel_z_0_27.data
z_0_28 = channel_z_0_28.data
z_0_29 = channel_z_0_29.data

# %% [markdown]
# ## x_1

# %%
x_1_1 = channel_x_1_1.data
x_1_2 = channel_x_1_2.data
x_1_3 = channel_x_1_3.data
x_1_4 = channel_x_1_4.data
x_1_5 = channel_x_1_5.data
x_1_6 = channel_x_1_6.data
x_1_7 = channel_x_1_7.data
x_1_8 = channel_x_1_8.data
x_1_9 = channel_x_1_9.data
x_1_10 = channel_x_1_10.data
x_1_11 = channel_x_1_11.data
x_1_12 = channel_x_1_12.data
x_1_13 = channel_x_1_13.data
x_1_14 = channel_x_1_14.data
x_1_15 = channel_x_1_15.data
x_1_16 = channel_x_1_16.data
x_1_17 = channel_x_1_17.data
x_1_18 = channel_x_1_18.data
x_1_19 = channel_x_1_19.data
x_1_20 = channel_x_1_20.data
x_1_21 = channel_x_1_21.data
x_1_22 = channel_x_1_22.data
x_1_23 = channel_x_1_23.data
x_1_24 = channel_x_1_24.data
x_1_25 = channel_x_1_25.data
x_1_26 = channel_x_1_26.data
x_1_27 = channel_x_1_27.data
x_1_28 = channel_x_1_28.data
x_1_29 = channel_x_1_29.data

# %% [markdown]
# ## y_1

# %%
y_1_1 = channel_y_1_1.data
y_1_2 = channel_y_1_2.data
y_1_3 = channel_y_1_3.data
y_1_4 = channel_y_1_4.data
y_1_5 = channel_y_1_5.data
y_1_6 = channel_y_1_6.data
y_1_7 = channel_y_1_7.data
y_1_8 = channel_y_1_8.data
y_1_9 = channel_y_1_9.data
y_1_10 = channel_y_1_10.data
y_1_11 = channel_y_1_11.data
y_1_12 = channel_y_1_12.data
y_1_13 = channel_y_1_13.data
y_1_14 = channel_y_1_14.data
y_1_15 = channel_y_1_15.data
y_1_16 = channel_y_1_16.data
y_1_17 = channel_y_1_17.data
y_1_18 = channel_y_1_18.data
y_1_19 = channel_y_1_19.data
y_1_20 = channel_y_1_20.data
y_1_21 = channel_y_1_21.data
y_1_22 = channel_y_1_22.data
y_1_23 = channel_y_1_23.data
y_1_24 = channel_y_1_24.data
y_1_25 = channel_y_1_25.data
y_1_26 = channel_y_1_26.data
y_1_27 = channel_y_1_27.data
y_1_28 = channel_y_1_28.data
y_1_29 = channel_y_1_29.data

# %% [markdown]
# ## z_1

# %%
z_1_1 = channel_z_1_1.data
z_1_2 = channel_z_1_2.data
z_1_3 = channel_z_1_3.data
z_1_4 = channel_z_1_4.data
z_1_5 = channel_z_1_5.data
z_1_6 = channel_z_1_6.data
z_1_7 = channel_z_1_7.data
z_1_8 = channel_z_1_8.data
z_1_9 = channel_z_1_9.data
z_1_10 = channel_z_1_10.data
z_1_11 = channel_z_1_11.data
z_1_12 = channel_z_1_12.data
z_1_13 = channel_z_1_13.data
z_1_14 = channel_z_1_14.data
z_1_15 = channel_z_1_15.data
z_1_16 = channel_z_1_16.data
z_1_17 = channel_z_1_17.data
z_1_18 = channel_z_1_18.data
z_1_19 = channel_z_1_19.data
z_1_20 = channel_z_1_20.data
z_1_21 = channel_z_1_21.data
z_1_22 = channel_z_1_22.data
z_1_23 = channel_z_1_23.data
z_1_24 = channel_z_1_24.data
z_1_25 = channel_z_1_25.data
z_1_26 = channel_z_1_26.data
z_1_27 = channel_z_1_27.data
z_1_28 = channel_z_1_28.data
z_1_29 = channel_z_1_29.data

# %% [markdown]
# # 拼接数据

# %%
x_0 = np.concatenate((x_0_1,x_0_2,x_0_3,x_0_4,x_0_5,x_0_6,x_0_7,x_0_8,x_0_9,x_0_10,x_0_11,x_0_12,x_0_13,x_0_14,x_0_15,x_0_16,x_0_17,x_0_18,x_0_19,x_0_20,x_0_21,x_0_22,x_0_23,x_0_24,x_0_25,x_0_26,x_0_27,x_0_28,x_0_29))
y_0 = np.concatenate((y_0_1,y_0_2,y_0_3,y_0_4,y_0_5,y_0_6,y_0_7,y_0_8,y_0_9,y_0_10,y_0_11,y_0_12,y_0_13,y_0_14,y_0_15,y_0_16,y_0_17,y_0_18,y_0_19,y_0_20,y_0_21,y_0_22,y_0_23,y_0_24,y_0_25,y_0_26,y_0_27,y_0_28,y_0_29))
z_0 = np.concatenate((z_0_1,z_0_2,z_0_3,z_0_4,z_0_5,z_0_6,z_0_7,z_0_8,z_0_9,z_0_10,z_0_11,z_0_12,z_0_13,z_0_14,z_0_15,z_0_16,z_0_17,z_0_18,z_0_19,z_0_20,z_0_21,z_0_22,z_0_23,z_0_24,z_0_25,z_0_26,z_0_27,z_0_28,z_0_29))
x_1 = np.concatenate((x_1_1,x_1_2,x_1_3,x_1_4,x_1_5,x_1_6,x_1_7,x_1_8,x_1_9,x_1_10,x_1_11,x_1_12,x_1_13,x_1_14,x_1_15,x_1_16,x_1_17,x_1_18,x_1_19,x_1_20,x_1_21,x_1_22,x_1_23,x_1_24,x_1_25,x_1_26,x_1_27,x_1_28,x_1_29))
y_1 = np.concatenate((y_1_1,y_1_2,y_1_3,y_1_4,y_1_5,y_1_6,y_1_7,y_1_8,y_1_9,y_1_10,y_1_11,y_1_12,y_1_13,y_1_14,y_1_15,y_1_16,y_1_17,y_1_18,y_1_19,y_1_20,y_1_21,y_1_22,y_1_23,y_1_24,y_1_25,y_1_26,y_1_27,y_1_28,y_1_29))
z_1 = np.concatenate((z_1_1,z_1_2,z_1_3,z_1_4,z_1_5,z_1_6,z_1_7,z_1_8,z_1_9,z_1_10,z_1_11,z_1_12,z_1_13,z_1_14,z_1_15,z_1_16,z_1_17,z_1_18,z_1_19,z_1_20,z_1_21,z_1_22,z_1_23,z_1_24,z_1_25,z_1_26,z_1_27,z_1_28,z_1_29))

# %% [markdown]
# # 绘图

# %%
plt.figure(figsize=(32,16)) # 设定画图板尺寸
plt.plot(x_1)
plt.savefig(r'D:\data\20190513\04\x_1.jpg')
plt.show()

# %%
plt.figure(figsize=(32,16)) # 设定画图板尺寸
plt.plot(y_1)
plt.savefig(r'D:\data\20190513\04\y_1.jpg')
plt.show()

# %%
plt.figure(figsize=(32,16)) # 设定画图板尺寸
plt.plot(z_1)
plt.savefig(r'D:\data\20190513\04\z_1.jpg')
plt.show()

# %% [markdown]
# # 存储

# %%
import pandas as pd
import numpy as np
import csv

data_20190513 = {
    'x_0':x_0,
    'y_0':y_0,
    'z_0':z_0,
    'x_1':x_1,
    'y_1':y_1,
    'z_1':z_1,
}
print(data_20190513)
# Out:
# {'x_0': array([-0.00368363,  0.00536984, -0.00250053, ...,  0.01063138,
#        -0.01138538,  0.00316679]), 'y_0': array([-0.0027144 ,  0.00579071, -0.00273907, ...,  0.01169521,
#        -0.01151836,  0.00422651]), 'z_0': array([-0.00431287,  0.00425255, -0.00331897, ...,  0.00966215,
#        -0.01144296,  0.00257182]), 'x_1': array([ 0.00236207,  0.00891638,  0.00441021, ...,  0.01254243,
#        -0.00148469,  0.00634593]), 'y_1': array([-0.0033505 ,  0.00351501, -0.00194395, ...,  0.00775248,
#        -0.00864768,  0.00179452]), 'z_1': array([-0.00316954,  0.00347251, -0.00042498, ...,  0.00684905,
#        -0.00636375,  0.00014669])}

# %% [markdown]
# import csv
# with open('test.csv','w')as f:
#     w=csv.writer(f,delimiter=",")
#     w.writerow(x_0)

# %% [markdown]
# # 绘图

# %%
import linecache
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

fig=plt.figure()

#绘制4条完整曲线
plt.plot(data_20190513,color='red')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-2673cef20c29> in <module>
#       9
#      10 #绘制4条完整曲线
# ---> 11 plt.plot(data_20190513,color='red')
#      12
#      13 plt.show()
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...

# %%
channel_x0 = tdms_file.object(group_name, 'x_0')
channel_y0 = tdms_file.object(group_name, 'y_0')
channel_z0 = tdms_file.object(group_name, 'z_0')
channel_x1 = tdms_file.object(group_name, 'x_1')
channel_y1 = tdms_file.object(group_name, 'y_1')
channel_z1 = tdms_file.object(group_name, 'z_1')

# set data from channels

x_0 = channel_x0.data
y_0 = channel_y0.data
z_0 = channel_z0.data
x_1 = channel_x1.data
y_1 = channel_y1.data
z_1 = channel_z1.data

print(x0)
