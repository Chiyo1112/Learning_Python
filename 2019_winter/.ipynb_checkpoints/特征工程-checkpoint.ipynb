# %% [markdown]
# # Prepare

# %%
from nptdms import TdmsFile
import numpy as np
import pandas as pd

# %%
#set Tdms file path
tdms20190513_01_01 = TdmsFile(r'D:\data\20190513\01\Acc 05-13-19 时间 100515.tdms')
tdms20190513_01_02 = TdmsFile(r'D:\data\20190513\01\Acc 05-13-19 时间 100615.tdms')
tdms20190513_01_03 = TdmsFile(r'D:\data\20190513\01\Acc 05-13-19 时间 100715.tdms')
tdms20190513_01_04 = TdmsFile(r'D:\data\20190513\01\Acc 05-13-19 时间 100816.tdms')

tdms20190513_01_11 = TdmsFile(r'D:\data\20190513\01\Current&Volage 05-13-19 时间 100515.tdms')
tdms20190513_01_12 = TdmsFile(r'D:\data\20190513\01\Current&Volage 05-13-19 时间 100615.tdms')
tdms20190513_01_13 = TdmsFile(r'D:\data\20190513\01\Current&Volage 05-13-19 时间 100715.tdms')
tdms20190513_01_14 = TdmsFile(r'D:\data\20190513\01\Current&Volage 05-13-19 时间 100816.tdms')


#set Tdms file path
tdms20190513_13_01 = TdmsFile(r'D:\data\20190513\13\Acc 05-13-19 时间 195300.tdms')
tdms20190513_13_11 = TdmsFile(r'D:\data\20190513\13\Current&Volage 05-13-19 时间 195300.tdms')

# %%
class TDMS_Vibration():
    def __init__(self, tdmsfile):
        self.tdmsfile = tdmsfile
        group_name = 'Measured Data'
        
        channel_x_0 = tdmsfile.object(group_name, 'x_0')
        channel_y_0 = tdmsfile.object(group_name, 'y_0')
        channel_z_0 = tdmsfile.object(group_name, 'z_0')
        channel_x_1 = tdmsfile.object(group_name, 'x_1')
        channel_y_1 = tdmsfile.object(group_name, 'y_1')
        channel_z_1 = tdmsfile.object(group_name, 'z_1')
        
        self.data_x_0 = channel_x_0.data
        self.data_y_0 = channel_y_0.data
        self.data_z_0 = channel_z_0.data
        self.data_x_1 = channel_x_1.data
        self.data_y_1 = channel_y_1.data
        self.data_z_1 = channel_z_1.data
        
    def x_0(self):
        return self.data_x_0
    
    def y_0(self):
        return self.data_y_0
    
    def z_0(self):
        return self.data_z_0
    
    def x_1(self):
        return self.data_x_1
    
    def y_1(self):
        return self.data_y_1

    def z_1(self):
        return self.data_z_1

# %%
class TDMS_Power():
    def __init__(self, tdmsfile):
        self.tdmsfile = tdmsfile
        group_name = 'Measured Data'
        
        channel_power = tdmsfile.object(group_name, 'Power')
        self.data_power = channel_power.data

        
    def power(self):
        return self.data_power

# %%
vibration_20190153_01_01 = TDMS_Vibration(tdms20190513_01_01)
vibration_20190153_01_02 = TDMS_Vibration(tdms20190513_01_02)
vibration_20190153_01_03 = TDMS_Vibration(tdms20190513_01_03)
vibration_20190153_01_04 = TDMS_Vibration(tdms20190513_01_04)

power_20190153_01_01 = TDMS_Power(tdms20190513_01_11)
power_20190153_01_02 = TDMS_Power(tdms20190513_01_12)
power_20190153_01_03 = TDMS_Power(tdms20190513_01_13)
power_20190153_01_04 = TDMS_Power(tdms20190513_01_14)


vibration_20190153_13 = TDMS_Vibration(tdms20190513_13_01)
power_20190153_13 = TDMS_Power(tdms20190513_13_11)

# %%
vibration_20190153_01_x_0 = np.concatenate((vibration_20190153_01_01.x_0(), vibration_20190153_01_02.x_0(), vibration_20190153_01_03.x_0(), vibration_20190153_01_04.x_0()))
vibration_20190153_01_y_0 = np.concatenate((vibration_20190153_01_01.y_0(), vibration_20190153_01_02.y_0(), vibration_20190153_01_03.y_0(), vibration_20190153_01_04.y_0()))
vibration_20190153_01_z_0 = np.concatenate((vibration_20190153_01_01.z_0(), vibration_20190153_01_02.z_0(), vibration_20190153_01_03.z_0(), vibration_20190153_01_04.z_0()))

vibration_20190153_01_x_1 = np.concatenate((vibration_20190153_01_01.x_1(), vibration_20190153_01_02.x_1(), vibration_20190153_01_03.x_1(), vibration_20190153_01_04.x_1()))
vibration_20190153_01_y_1 = np.concatenate((vibration_20190153_01_01.y_1(), vibration_20190153_01_02.y_1(), vibration_20190153_01_03.y_1(), vibration_20190153_01_04.y_1()))
vibration_20190153_01_z_1 = np.concatenate((vibration_20190153_01_01.z_1(), vibration_20190153_01_02.z_1(), vibration_20190153_01_03.z_1(), vibration_20190153_01_04.z_1()))

power_20190153_01_power = np.concatenate((power_20190153_01_01.power(), power_20190153_01_02.power(), power_20190153_01_03.power(), power_20190153_01_04.power()))

# %%
vibration_20190153_13_x_0 = vibration_20190153_13.x_0()
vibration_20190153_13_y_0 = vibration_20190153_13.y_0()
vibration_20190153_13_z_0 = vibration_20190153_13.z_0()

vibration_20190153_13_x_1 = vibration_20190153_13.x_1()
vibration_20190153_13_y_1 = vibration_20190153_13.y_1()
vibration_20190153_13_z_1 = vibration_20190153_13.z_1()
power_20190153_13_power = power_20190153_13.power()

# %% [markdown]
# # class EEMD

# %% [markdown]
# ### def DoFFT

# %%
from scipy import fftpack
def DoFFT(data, freq):
    n = len(data)
    yf = 2* abs(np.fft.fft(data)) / n
    xf = fftpack.rfftfreq(n, d=1/freq)*2
    return xf, yf

# %% [markdown]
# ### def DoEEMD

# %%
from PyEMD import EEMD
def DoEEMD(data, start, stop , freq, extrema_detection="parabol"):
    num = stop - start
    t = np.linspace(0, num/freq, num)
    
    eemd = EEMD()
    #eemd.FIE=XE_H = 10#设置停止条件
    emd = eemd.EMD
    emd.extrema_detection = extrema_detection
    
    eIMFs = eemd.eemd(data[start : stop], t)
    nIMFs = eIMFs.shape[0]
    
    return nIMFs, eIMFs

# %% [markdown]
# ### def Draw_EEMD_Original_FFT_Compare

# %%
def Draw_EEMD_Original_FFT_Compare(data_1, nIMFs_1, eIMFs_1, freq_1, start_1, stop_1 , 
                                   data_2, nIMFs_2, eIMFs_2, freq_2, start_2, stop_2 , 
                                   colour_11 = 'navy', colour_12 = 'dodgerblue',  colour_21 = 'red', colour_22 = 'deeppink', size = (24, 32), alpha_num = 0.6):
    num_1 = stop_1 - start_1
    t_1 = np.linspace(0, num_1/freq_1, num_1)
    num_2 = stop_2 - start_2
    t_2 = np.linspace(0, num_2/freq_2, num_2)
    
    plt.figure(figsize=size)
    plt.subplot(nIMFs_1+1, 2, 1)
    plt.plot(t_1, data_1[start_1: stop_1],  colour_11, alpha = alpha_num)
    plt.plot(t_2, data_2[start_2: stop_2],  colour_21, alpha = alpha_num)
    
    plt.subplot(nIMFs_1+1, 2, 2)
    plt.plot(DoFFT(data_1[start_1 : stop_1], freq_1)[0], DoFFT(data_1[start_1 : stop_1], freq_1)[1],  colour_11, alpha = alpha_num)
    plt.plot(DoFFT(data_2[start_2 : stop_2], freq_2)[0], DoFFT(data_2[start_2 : stop_2], freq_2)[1],  colour_21, alpha = alpha_num)
    plt.xlim(0, freq_1/2)

    for n in range(nIMFs_1):
        if n < 100:#不局限于10
            plt.subplot(nIMFs_1+1, 2, (n+1)*2+1)
            plt.plot(t_1, eIMFs_1[n], colour_12, alpha = alpha_num)
            plt.plot(t_2, eIMFs_2[n], colour_22, alpha = alpha_num)
            plt.ylabel("eIMF %i" %(n+1))
            plt.locator_params(axis='y', nbins=5)

            plt.subplot(nIMFs_1+1, 2, (n+1)*2+2)
            plt.plot(DoFFT(eIMFs_1[n], freq_1)[0], DoFFT(eIMFs_1[n], freq_1)[1], colour_12, alpha = alpha_num)
            plt.plot(DoFFT(eIMFs_2[n], freq_2)[0], DoFFT(eIMFs_2[n], freq_2)[1], colour_22, alpha = alpha_num)
            plt.ylabel("eIMF %i" %(n+1))
            plt.locator_params(axis='y', nbins=5)
            plt.xlim(0, freq_1/2)
        else:
            continue

    plt.xlabel("Time [s]")
    plt.tight_layout()
    plt.savefig('eemd_example', dpi=120)
    plt.show()

# %% [markdown]
# # Choose Data

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
start_num = 200000
stop_num = 200500
plt.plot(vibration_20190153_13_y_1)
plt.plot(vibration_20190153_01_y_1)
plt.xlim(0, stop_num)
plt.ylim(-0.1, 0.1)
# Out:
# (-0.1, 0.1)

# %%
plt.plot(vibration_20190153_13_x_1)
plt.plot(vibration_20190153_01_x_1)
plt.xlim(start_num, stop_num)
plt.ylim(-0.03, 0.03)
# Out:
# (-0.03, 0.03)

# %% [markdown]
# ## Calculate

# %% [markdown]
# ### 进行EEMD

# %%
x_0_new_EEMD = DoEEMD(vibration_20190153_01_x_0, start_num, stop_num, freq = 1000, extrema_detection="parabol")
x_0_old_EEMD = DoEEMD(vibration_20190153_13_x_0, start_num, stop_num, freq = 1000, extrema_detection="parabol")
y_0_new_EEMD = DoEEMD(vibration_20190153_01_y_0, start_num, stop_num, freq = 1000, extrema_detection="parabol")
y_0_old_EEMD = DoEEMD(vibration_20190153_13_y_0, start_num, stop_num, freq = 1000, extrema_detection="parabol")
z_0_new_EEMD = DoEEMD(vibration_20190153_01_z_0, start_num, stop_num, freq = 1000, extrema_detection="parabol")
z_0_old_EEMD = DoEEMD(vibration_20190153_13_z_0, start_num, stop_num, freq = 1000, extrema_detection="parabol")

# %%
x_1_new_EEMD = DoEEMD(vibration_20190153_01_x_1, start_num, stop_num, freq = 1000, extrema_detection="parabol")
x_1_old_EEMD = DoEEMD(vibration_20190153_13_x_1, start_num, stop_num, freq = 1000, extrema_detection="parabol")
y_1_new_EEMD = DoEEMD(vibration_20190153_01_y_1, start_num, stop_num, freq = 1000, extrema_detection="parabol")
y_1_old_EEMD = DoEEMD(vibration_20190153_13_y_1, start_num, stop_num, freq = 1000, extrema_detection="parabol")
z_1_new_EEMD = DoEEMD(vibration_20190153_01_z_1, start_num, stop_num, freq = 1000, extrema_detection="parabol")
z_1_old_EEMD = DoEEMD(vibration_20190153_13_z_1, start_num, stop_num, freq = 1000, extrema_detection="parabol")

# %%
Draw_EEMD_Original_FFT_Compare(data_1 = vibration_20190153_01_x_0, 
                                   nIMFs_1 = x_0_new_EEMD[0], 
                                   eIMFs_1 = x_0_new_EEMD[1], 
                                   freq_1 = 1000, 
                                   start_1 = start_num, 
                                   stop_1 = stop_num, 
                                   data_2 = vibration_20190153_13_x_0, 
                                   nIMFs_2 = x_0_old_EEMD[0], 
                                   eIMFs_2 = x_0_old_EEMD[1], 
                                   freq_2 = 1000, 
                                   start_2 = start_num, 
                                   stop_2 = stop_num)

# %% [markdown]
# # Anasys

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %% [markdown]
# #### 每个IMF值

# %%
plt.plot(x_0_new_EEMD[1][6])

# %% [markdown]
# ## 创建矩阵

# %% [markdown]
# #### 创建空矩阵

# %%
row = x_0_new_EEMD[0]
line = np.size(x_0_new_EEMD[1][0])

data_EMD = [None]*row
for i in range(row):
    data_EMD[i] = [None]*line

# %% [markdown]
# #### 创建赋值矩阵

# %%
def IMF_Analysis(data):
    row = data[0]
    line = np.size(data[1][0])
    matrix = [None]*row
    for i in range(row):
        matrix[i] = data[1][i]
        
    return matrix

# %%
x_0_new_IMF_analysis = IMF_Analysis(x_0_new_EEMD)
x_0_old_IMF_analysis = IMF_Analysis(x_0_old_EEMD)
y_0_new_IMF_analysis = IMF_Analysis(y_0_new_EEMD)
y_0_old_IMF_analysis = IMF_Analysis(y_0_old_EEMD)
z_0_new_IMF_analysis = IMF_Analysis(z_0_new_EEMD)
z_0_old_IMF_analysis = IMF_Analysis(z_0_old_EEMD)

x_1_new_IMF_analysis = IMF_Analysis(x_1_new_EEMD)
x_1_old_IMF_analysis = IMF_Analysis(x_1_old_EEMD)
y_1_new_IMF_analysis = IMF_Analysis(y_1_new_EEMD)
y_1_old_IMF_analysis = IMF_Analysis(y_1_old_EEMD)
z_1_new_IMF_analysis = IMF_Analysis(z_1_new_EEMD)
z_1_old_IMF_analysis = IMF_Analysis(z_1_old_EEMD)

# %%
row = x_0_new_EEMD[0]
line = np.size(x_0_new_EEMD[1][0])

data_x_0_EMD = [None]*row
for i in range(row):
    data_x_0_EMD[i] = x_0_new_EEMD[1][i]#.reshape(-1, 1)

# %%
np.shape(x_0_new_EEMD)
# Out:
# (7, 500)

# %% [markdown]
# #### 标准化

# %%
from sklearn.preprocessing import StandardScaler
b = StandardScaler().fit_transform(data_x_0_EMD[0])#.reshape(-1, 1))

# %%
plt.plot(b)
#plt.plot(data_x_0_EMD[0])

# %% [markdown]
# #### 归一化

# %%
from sklearn.preprocessing import MinMaxScaler
c = MinMaxScaler().fit_transform(data_x_0_EMD[0])

# %%
plt.plot(c)

# %% [markdown]
# #### L2归一化

# %%
from sklearn.preprocessing import Normalizer
d = Normalizer().fit_transform(data_x_0_EMD[0])

# %%
plt.plot(d)

# %%
for i in range(row):
    R = data_x_0_EMD[i]
    R_mean = np.mean(R) #计算均值
    R_var = np.var(R)  #计算方差
    R_sc = np.mean((R - R_mean) ** 3)  #计算偏斜度
    R_ku = np.mean((R - R_mean) ** 4) / pow(R_var, 2) #计算峰度
    print(R_mean)
    print(R_var)
    print(R_sc)
    print(R_ku)
# Out:
# 4.730739635748967e-05
# 2.4466002725518005e-05
# -4.461669199208416e-09
# 1.9512730701700127
# -3.7788819562483184e-05
# 5.526124857512733e-06
# 1.0031020242003325e-09
# 3.2376255158467004
# 0.00010138235649366042
# 2.037393563964586e-06
# -4.0931351382404664e-10
# 2.8319576816874954
# -7.1326229040875826e-06
# 9.97069365333243e-07
# 5.441334727700486e-11
# 2.2755533545228035
# -2.0681915672559848e-06
# 2.249276503194612e-07
# 2.0839238615004836e-11
# 3.590757670536465
# 1.9091840600491904e-05
# 1.29158709910417e-07
# -2.0130525493962272e-11
# 2.3395422957557668
# -0.004470495617538983
# 6.020921912411799e-09
# 3.493174683382103e-13
# 1.8746668537900701

# %%
from numpy import log1p
from sklearn.preprocessing import FunctionTransformer

#自定义转换函数为对数函数的数据变换
#第一个参数是单变元函数
FunctionTransformer(log1p).fit_transform(iris.data)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\preprocessing\_function_transformer.py:98: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# D:\Anaconda3\lib\site-packages\sklearn\preprocessing\_function_transformer.py:98: FutureWarning: The default validate=True will be replaced by validate=False in 0.22.
#   "validate=False in 0.22.", FutureWarning)
# array([[1.80828877, 1.5040774 , 0.87546874, 0.18232156],
#        [1.77495235, 1.38629436, 0.87546874, 0.18232156],
#        [1.74046617, 1.43508453, 0.83290912, 0.18232156],
#        [1.7227666 , 1.41098697, 0.91629073, 0.18232156],
#        [1.79175947, 1.5260563 , 0.87546874, 0.18232156],
#        [1.85629799, 1.58923521, 0.99325177, 0.33647224],
#        [1.7227666 , 1.48160454, 0.87546874, 0.26236426],
#        [1.79175947, 1.48160454, 0.91629073, 0.18232156],
#        [1.68639895, 1.36097655, 0.87546874, 0.18232156],
# ...

# %% [markdown]
# # 降维

# %%
#M =np.vstack((x_0_new_IMF_analysis[0], y_0_new_IMF_analysis[0], z_0_new_IMF_analysis[0]))
pca_before =np.hstack((x_0_new_IMF_analysis[0].reshape(-1, 1), y_0_new_IMF_analysis[0].reshape(-1, 1), z_0_new_IMF_analysis[0].reshape(-1, 1),
             x_1_new_IMF_analysis[0].reshape(-1, 1), y_1_new_IMF_analysis[0].reshape(-1, 1), z_1_new_IMF_analysis[0].reshape(-1, 1)))
np.shape(pca_before)
# Out:
# (500, 6)

# %% [markdown]
# ## 主成分分析法（PCA）

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
#主成分分析法，返回降维后的数据
#参数n_components为主成分数目
#N = N.transpose()
pca_after = pca.fit_transform(pca_before)
np.shape(pca_after)
# Out:
# (500, 2)

# %%
np.shape(iris.target)
# Out:
# (150,)

# %%
np.shape(iris.data)
# Out:
# (150, 4)

# %%
a = [0] * 125
b = [1] * 125
c = [2] * 125
d = [3] * 125
e = np.hstack((a, b, c, d))
np.shape(e)
# Out:
# (500,)

# %%
plt.figure()
plt.scatter(pca_answer[:, 0], pca_answer[:, 1], c = e, alpha=.8)
plt.legend()
plt.title('PCA of Vibration')
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Text(0.5, 1.0, 'PCA of Vibration')

# %%
print('各主成分贡献度:{}'.format(pca.explained_variance_ratio_))
# Out:
# 各主成分贡献度:[0.71921691 0.23057488]

# %%
print('各主成分贡献度:{}'.format(pca.explained_variance_ratio_))
# Out:
# 各主成分贡献度:[0.65122856 0.24550941]

# %%
X_new = pca.inverse_transform(pca_answer)
plt.scatter(X[:, 0], X[:, 1], alpha=0.2)
plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)
plt.axis('equal');

# %%
digits.data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-e995ae4f0702> in <module>
# ----> 1 digits.data
#
# NameError: name 'digits' is not defined

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
#主成分分析法，返回降维后的数据
#参数n_components为主成分数目
#N = N.transpose()
pca_iris = pca.fit_transform(iris.data)
np.shape(pca_iris)
# Out:
# (150, 2)

# %%
plt.figure()
plt.scatter(pca_iris[:, 0], pca_iris[:, 1], c = iris.target, alpha=.8)
plt.legend()
plt.title('PCA of Vibration')
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Text(0.5, 1.0, 'PCA of Vibration')
